# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('correlation.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_MRP  Item_Outlet_Sales
# 0           FDA15         9.30  249.8092          3735.1380
# 1           DRC01         5.92   48.2692           443.4228
# 2           FDN15        17.50  141.6180          2097.2700
# 3           FDX07        19.20  182.0950           732.3800
# 4           NCD19         8.93   53.8614           994.7052

# %%
data[['Item_Weight','Item_MRP']].corr()
# Out:
#              Item_Weight  Item_MRP
# Item_Weight     1.000000  0.027141
# Item_MRP        0.027141  1.000000

# %%
data[['Item_Weight','Item_Outlet_Sales']].corr()
# Out:
#                    Item_Weight  Item_Outlet_Sales
# Item_Weight           1.000000           0.014123
# Item_Outlet_Sales     0.014123           1.000000

# %%
data[['Item_Outlet_Sales','Item_MRP']].corr()
# Out:
#                    Item_Outlet_Sales  Item_MRP
# Item_Outlet_Sales           1.000000  0.567574
# Item_MRP                    0.567574  1.000000

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
import seaborn as sns

# %%
data.corr()
# Out:
# /var/folders/s7/2zz28zhd1zdc7snw1lnwl8540000gn/T/ipykernel_1849/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Item_Weight  Item_MRP  Item_Outlet_Sales
# Item_Weight           1.000000  0.027141           0.014123
# Item_MRP              0.027141  1.000000           0.567574
# Item_Outlet_Sales     0.014123  0.567574           1.000000

# %%
cor=data.corr()
plt.figure(figsize=(16,210))
sns.heatmap(cor)
# Out:
# /var/folders/s7/2zz28zhd1zdc7snw1lnwl8540000gn/T/ipykernel_1849/3339955104.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data.corr()
# <Axes: >
